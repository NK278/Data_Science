# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Ans: Matplotlib is a widely used Python library for creating static, interactive, and animated visualizations in a variety of formats. It provides a high-level interface for drawing attractive and informative statistical graphics. Matplotlib is used extensively in data visualization and scientific plotting due to its flexibility, versatility, and ease of use.
#
# Pyplot is a sub-module within Matplotlib that provides a collection of functions that are similar to MATLAB's plotting functions. It's commonly used for creating simple plots quickly and easily.
#
# Five plots that can be plotted using the Pyplot module of Matplotlib are:
#
# 1)Line Plot: A simple plot that represents data points with individual markers connected by straight lines. It's useful for visualizing trends over continuous data points.
#
# 2)Bar Plot: A plot that uses rectangular bars to represent data. It's commonly used for comparing categorical data or showing counts and frequencies.
#
# 3)Histogram: A plot used to display the distribution of a continuous variable. It groups data into bins and displays the frequency or density of observations in each bin.
#
# 4)Scatter Plot: A plot that displays individual data points as markers in a 2D space. It's useful for exploring relationships between two continuous variables.
#
# 5)Pie Chart: A circular chart that displays data as slices of a pie. It's suitable for showing the composition or distribution of categorical data.

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %% [markdown]
# Ans: A scatter plot is a type of data visualization that uses dots or markers to represent individual data points in a two-dimensional space. It's particularly useful for visualizing the relationship between two continuous variables. Each point on the scatter plot corresponds to a pair of values, one along the x-axis and another along the y-axis.

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.title('PLOT')
plt.xlabel('x-->')
plt.ylabel('y-->')
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:

# %% [markdown]
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# Ans: The subplot() function in Matplotlib is used to create a grid of plots within a single figure. It's particularly useful when you want to display multiple plots side by side or in a grid pattern. The function takes three arguments: the number of rows, the number of columns, and the index of the current plot within the grid.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the four line plots
x = np.array([0, 1, 2, 3, 4, 5])

y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create a 2x2 grid of plots
plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title('Line Plot 1')

plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title('Line Plot 2')

plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title('Line Plot 3')

plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title('Line Plot 4')

# Adjust layout for better spacing
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# Ans: A bar plot is a type of data visualization that uses rectangular bars to represent data. It's commonly used for comparing the values of different categories or showing counts, frequencies, or measurements associated with those categories. In a bar plot, the length or height of each bar is proportional to the value it represents.
#
# Bar plots are used to:
#
# >Compare values among different categories.
# >Display data that can be divided into distinct categories.
# >Show trends or patterns in data.

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Create a vertical bar plot
plt.figure(figsize=(8, 5))  # Set figure size
plt.bar(company, profit, color='blue')
plt.title('Company Profits')
plt.xlabel('Company')
plt.ylabel('Profit')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

plt.show()

# Create a horizontal bar plot
plt.figure(figsize=(8, 5))  # Set figure size
plt.barh(company, profit, color='green')
plt.title('Company Profits')
plt.xlabel('Profit')
plt.ylabel('Company')

plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# Ans:A box plot, also known as a box-and-whisker plot, is a graphical representation of the distribution of a dataset. It displays the summary statistics of a dataset, such as the minimum, first quartile (25th percentile), median (second quartile or 50th percentile), third quartile (75th percentile), and maximum. Additionally, box plots can help identify potential outliers in the data.
#
# Box plots are used to:
#
# ->Show the distribution and spread of data.
# ->Identify the presence of outliers.
# ->Compare distributions across different categories or groups.

# %%
import numpy as np
import matplotlib.pyplot as plt

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Create a box plot
plt.figure(figsize=(8, 5))  # Set figure size
plt.boxplot([box1, box2], labels=['Box 1', 'Box 2'])
plt.title('Box Plot')
plt.ylabel('Values')

plt.show()
